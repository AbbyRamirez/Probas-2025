# %%
sel = int(input("ingrese 1 para esfera, 2 para cilindro, 3 para cono: "))

while sel < 1 or sel > 3:
    sel = int(input("ingrese 1 para esfera, 2 para cilindro, 3 para cono: "))

if sel == 1:
    r = float(input("ingrese el radio: "))
    h = float(input("ingrese la altura: "))

    A = 2 * 3.1416 * r * (h + r)
    V = 3.1416 * r ** 2 * h
    print("el area es ",A,"y el volumen es",V)

if sel == 2:
    r = float(input("ingrese el radio: "))
    h = float(input("ingrese la altura: "))
    A = 2 * 3.1416 * r * (h + r)
    V = 3.1416 * r ** 2 * h
    print("el area es ",A,"y el volumen es",V)

if sel == 3:
    r = float(input("ingrese el radio: "))
    h = float(input("ingrese la altura: "))
    A = 3.1416 * r * (r + (h ** 2 + r ** 2) ** (1/2))
    V = (1/3) * 3.1416 * r ** 2 * h
    print("el area es ",A,"y el volumen es",V)
# Out:
# ingrese 1 para esfera, 2 para cilindro, 3 para cono: 7
# ingrese 1 para esfera, 2 para cilindro, 3 para cono: 2
# ingrese el radio: 7
# ingrese la altura: 9
# el area es  703.7184 y el volumen es 1385.4456
