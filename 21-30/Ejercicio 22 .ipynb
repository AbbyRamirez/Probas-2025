# %%
import random

def lanzar_dado():
    return random.randint(1, 6)

def lanzar_moneda():
    return random.choice(["Cara", "Cruz"])

def main():
    print("Simulador de lanzamiento de dado y moneda")
    print("-----------------------------------------------")

    while True:
        print("1. Lanzar dado")
        print("2. Lanzar moneda")
        print("3. Salir")

        opcion = input("Ingrese su opción: ")

        if opcion == "1":
            resultado = lanzar_dado()
            print(f"El resultado del lanzamiento del dado es: {resultado}")
        elif opcion == "2":
            resultado = lanzar_moneda()
            print(f"El resultado del lanzamiento de la moneda es: {resultado}")
        elif opcion == "3":
            print("Hasta luego!")
            break
        else:
            print("Opción inválida. Por favor, intente de nuevo.")

if __name__ == "__main__":
    main()
# Out:
# Simulador de lanzamiento de dado y moneda
# -----------------------------------------------
# 1. Lanzar dado
# 2. Lanzar moneda
# 3. Salir
# Ingrese su opción: 2
# El resultado del lanzamiento de la moneda es: Cruz
# 1. Lanzar dado
# 2. Lanzar moneda
# 3. Salir
# Ingrese su opción: 1
# El resultado del lanzamiento del dado es: 1
# 1. Lanzar dado
# 2. Lanzar moneda
# 3. Salir
# Ingrese su opción: 3
# Hasta luego!
