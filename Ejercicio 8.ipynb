# %%
radio = int(input("escriba el radio de su circulo"))
peri = float()
area = float()

peri = 2 * radio * 3.14
area = radio ** 2 * 3.14

print("el perimetro es", peri ,"mientras que el area es", area)
# Out:
# escriba el radio de su circulo4
# el perimetro es 25.12 mientras que el area es 50.24
