# %%
tru = True
while tru:

  print("agenda de cotactos")
  print(" a: Agregar contacto")
  print(" b: Buscar contacto")
  print(" c: ver contactos")
  choice = input("seleccione una opcion")
  lista = []

  if choice == 'a':
    Nombre = input("agregar nombre")
    tup = (Nombre, input("agregar numero"),input("agregar correo"))
    lista.append(tup)
    print("contacto añadido")

  elif choice == 'b':
    nom = input("escriba el contacto a buscar")
    for tup in lista:
      if tup == nom:
        print (tup)

  elif choice == 'c':
    lista = lista.sort
    print(lista)

tru = True
# Out:
# agenda de cotactos
#  a: Agregar contacto
#  b: Buscar contacto
#  c: ver contactos
