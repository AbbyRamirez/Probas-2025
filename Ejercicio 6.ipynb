# %%
tiempo = float(input("ingrese cantidad en años"))
CI = float(input("ingrese capital inicial"))
TI = float(input("ingrese tasa de interes en decimales"))
CF = float ()

CF = CI * (1 + TI) ** tiempo

print("El capital final es", CF)
# Out:
# ingrese cantidad en años4
# ingrese capital inicial1200
# ingrese tasa de interes en decimales0.7
# El capital final es 10022.519999999999
