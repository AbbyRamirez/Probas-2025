# %%
 #Act1
print("hola mundo")
 #Act2
a = int(input("ingrese primer numero:"))
b = int(input("ingrese segundo numero:"))

print("adicion = ",a + b)
print("resta=", a - b)
print("mult =", a * b)
print("divi =", a / b)

if condicional:
  comandos
  elif condicion:
    comandos
  else
# Out:
# hola mundo
# ingrese primer numero:45
# ingrese segundo numero:67
# adicion =  112
# resta= -22
# mult = 3015
# divi = 0.6716417910447762
