# %%
n1 = int(input("ponga el primer numero: "))
n2 = int(input("ponga el segundo numero: "))
n3 = int(input("ponga el tercer numero: "))

if n1 > n2 :
  if n1 < n3 :
    print(n3,"es el numero mayor")
  else:
    print(n1,"es el nuemro mayor")
else:
  print(n2,"es el numero mayor")
# Out:
# ponga el primer numero: 6
# ponga el segundo numero: 3
# ponga el tercer numero: 9
# 9 es el numero mayor
