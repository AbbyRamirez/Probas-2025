# %%
Num = int(input("ingrese un numero"))
Res = Num
cont = Num - 1

while cont > 1:
  Res = Res * cont
  cont = cont - 1

print(res)
# Out:
# ingrese un numero6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-2e86fb0c390c> in <cell line: 0>()
#       7   cont = cont - 1
#       8
# ----> 9 print(res)
#      10
#      11
#
# NameError: name 'res' is not defined
