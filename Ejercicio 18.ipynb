# %%
a = int(input("ingrese el coeficiente del término cuadrático "))
b = int(input("ingrese el coeficiente del término lineal "))
c = int(input("ingrese el coeficiente del termino independiente"))
resultado1 = ((-b)-(b**2 - 4*a*c)**0.5)/2*a
resultado2 = ((-b)+(b**2 - 4*a*c)**0.5)/2*a
print("x1= ",resultado1)
print("x2= ",resultado2)
# Out:
# ingrese el coeficiente del término cuadrático 1
# ingrese el coeficiente del término lineal 2
# ingrese el coeficiente del termino independiente1
# x1=  -1.0
# x2=  -1.0
