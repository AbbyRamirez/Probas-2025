# %%
import random
lista = [random.randint(0, 100) for _ in range(10)]
print("Lista original:", lista)
def ordenamiento_por_seleccion(lista):
    for i in range(len(lista)):
        minimo = i
        for j in range(i + 1, len(lista)):
            if lista[j] < lista[minimo]:
                minimo = j
        lista[i], lista[minimo] = lista[minimo], lista[i]
    return lista
def ordenamiento_por_insercion(lista):
    for i in range(1, len(lista)):
        clave = lista[i]
        j = i - 1
        while j >= 0 and lista[j] > clave:
            lista[j + 1] = lista[j]
            j -= 1
        lista[j + 1] = clave
    return lista
def ordenamiento_por_burbuja(lista):
    for i in range(len(lista)):
        for j in range(len(lista) - 1):
            if lista[j] > lista[j + 1]:
                lista[j], lista[j + 1] = lista[j + 1], lista[j]
    return lista

print("Ordenamiento por selección:", ordenamiento_por_seleccion(lista[:]))
print("Ordenamiento por inserción:", ordenamiento_por_insercion(lista[:]))
print("Ordenamiento por burbuja:", ordenamiento_por_burbuja(lista[:]))
# Out:
# Lista original: [63, 49, 47, 68, 84, 85, 28, 68, 50, 4]
# Ordenamiento por selección: [4, 28, 47, 49, 50, 63, 68, 68, 84, 85]
# Ordenamiento por inserción: [4, 28, 47, 49, 50, 63, 68, 68, 84, 85]
# Ordenamiento por burbuja: [4, 28, 47, 49, 50, 63, 68, 68, 84, 85]
