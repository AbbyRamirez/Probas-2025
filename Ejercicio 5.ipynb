# %%
num = int(input("escribe un numero "))
n = num - 1
prim = float()

while n > 1:

  prim = num % n

  if prim == 0:
    print("no es primo")
    break
  else:
    n = n - 1

if prim == 1:
  print("es primo")
# Out:
# escribe un numero 11
# es primo
