# %%
n = int(input("Diga un tope "))
a = 0
b = 1
suma= int()

print(a)
print(b)

while True:
  suma = a + b
  print(suma)
  a = b
  b = suma

  if suma > n:
    break
# Out:
# Diga un tope 15
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21
