# %%
numero = int(input("diga un numero "))
residuo = int()
residuo_2 = int()
n = numero - 1


residuo = numero % 2

if residuo == 0:
  print("es par")

else:
  print("es impar")

while n > 1:
  residuo_2 = numero % n
  if residuo_2 == 0:
    print(n)
  n = n - 1
# Out:
# diga un numero 56
# es par
# 28
# 14
# 8
# 7
# 4
# 2
