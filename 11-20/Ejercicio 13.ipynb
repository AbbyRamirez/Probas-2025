# %%
temp = float(input("ingrese temp a convertir en celsius "))
tempF = float()
tempK = float()

tempF = (9/5) * temp + 32

tempK = temp + 273.15

print("kelvin ",tempK)
print("Fahrenheit ",tempF)
# Out:
# ingrese temp a convertir en celsius 38
# kelvin  311.15
# Fahrenheit  100.4
